# %% [markdown]
# # **Upload the Datasets**

# %%
# Create a Kaggle folder
# !mkdir ~/.kaggle

# %%
# Upload kaggle.json
from google.colab import files
files.upload()

# %%
# Move kaggle.json to the kaggle folder
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Upload dataset 1 from Kaggle: "Fitness Exercises"
# !kaggle datasets download -d omarxadel/fitness-exercises-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/omarxadel/fitness-exercises-dataset
# License(s): MIT
# fitness-exercises-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# Unzip dataset 1
import zipfile
import os

with zipfile.ZipFile("fitness-exercises-dataset.zip", 'r') as zip_ref:
    zip_ref.extractall("fitness_dataset")

os.listdir("fitness_dataset")
# Out:
# ['exercises.csv']

# %%
# Upload Dataset2.xlsx
from google.colab import files
files.upload()

# %% [markdown]
# # **Preprocessing of Dataset 1**

# %%
import pandas as pd

df = pd.read_csv("fitness_dataset/exercises.csv")
df.head()
# Out:
#      bodyPart    equipment                                         gifUrl  \
# 0       waist  body weight  https://v2.exercisedb.io/image/MOnK4iG0MEt9h8
# 1       waist  body weight  https://v2.exercisedb.io/image/PERWLDGUxVbpHS
# 2       waist  body weight  https://v2.exercisedb.io/image/PLr4yo3j-f1amp
# 3  upper legs  body weight  https://v2.exercisedb.io/image/XPQwM7HECjgNFE
# 4       waist  body weight  https://v2.exercisedb.io/image/5nYph4eUGNiEdf
#
#      id                     name target secondaryMuscles/0 secondaryMuscles/1  \
# 0     1               3/4 sit-up    abs        hip flexors         lower back
# 1     2            45° side bend    abs           obliques                NaN
# 2     3                 air bike    abs        hip flexors                NaN
# 3  1512  all fours squad stretch  quads         hamstrings             glutes
# 4     6  alternate heel touchers    abs           obliques                NaN
#
#                                       instructions/0  \
# 0  Lie flat on your back with your knees bent and...
# 1  Stand with your feet shoulder-width apart and ...
# 2  Lie flat on your back with your hands placed b...
# 3  Start on all fours with your hands directly un...
# 4  Lie flat on your back with your knees bent and...
#
#                                       instructions/1  ... instructions/5  \
# 0  Place your hands behind your head with your el...  ...            NaN
# 1  Keeping your back straight and your core engag...  ...            NaN
# 2  Lift your legs off the ground and bend your kn...  ...            NaN
# 3  Extend one leg straight back, keeping your kne...  ...            NaN
# 4  Extend your arms straight out to the sides, pa...  ...            NaN
#
#   secondaryMuscles/2 instructions/6 instructions/7 secondaryMuscles/3  \
# 0                NaN            NaN            NaN                NaN
# 1                NaN            NaN            NaN                NaN
# 2                NaN            NaN            NaN                NaN
# 3                NaN            NaN            NaN                NaN
# 4                NaN            NaN            NaN                NaN
#
#   instructions/8 secondaryMuscles/4 instructions/9 secondaryMuscles/5  \
# 0            NaN                NaN            NaN                NaN
# 1            NaN                NaN            NaN                NaN
# 2            NaN                NaN            NaN                NaN
# 3            NaN                NaN            NaN                NaN
# 4            NaN                NaN            NaN                NaN
#
#   instructions/10
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1324 entries, 0 to 1323
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bodyPart            1324 non-null   object
#  1   equipment           1324 non-null   object
#  2   gifUrl              1324 non-null   object
#  3   id                  1324 non-null   int64
#  4   name                1324 non-null   object
#  5   target              1324 non-null   object
#  6   secondaryMuscles/0  1324 non-null   object
#  7   secondaryMuscles/1  986 non-null    object
#  8   instructions/0      1324 non-null   object
#  9   instructions/1      1324 non-null   object
#  10  instructions/2      1324 non-null   object
#  11  instructions/3      1324 non-null   object
#  12  instructions/4      1242 non-null   object
#  13  instructions/5      739 non-null    object
#  14  secondaryMuscles/2  233 non-null    object
#  15  instructions/6      313 non-null    object
#  16  instructions/7      92 non-null     object
#  17  secondaryMuscles/3  32 non-null     object
#  18  instructions/8      20 non-null     object
#  19  secondaryMuscles/4  4 non-null      object
#  20  instructions/9      5 non-null      object
#  21  secondaryMuscles/5  2 non-null      object
#  22  instructions/10     3 non-null      object
# dtypes: int64(1), object(22)
# memory usage: 238.0+ KB

# %%
# Removal of the columns id, gifURL, all instructions and nearly zero secondary muscles (2-5)
df = df.drop(columns=[
      "id",
      "gifUrl",
      "secondaryMuscles/2",
      "secondaryMuscles/3",
      "secondaryMuscles/4",
      "secondaryMuscles/5",
      "instructions/0",
      "instructions/1",
      "instructions/2",
      "instructions/3",
      "instructions/4",
      "instructions/5",
      "instructions/6",
      "instructions/7",
      "instructions/8",
      "instructions/9",
      "instructions/10"
])

# %%
df
# Out:
#         bodyPart    equipment                                       name  \
# 0          waist  body weight                                 3/4 sit-up
# 1          waist  body weight                              45° side bend
# 2          waist  body weight                                   air bike
# 3     upper legs  body weight                    all fours squad stretch
# 4          waist  body weight                    alternate heel touchers
# ...          ...          ...                                        ...
# 1319       chest  body weight  wide-grip chest dip on high parallel bars
# 1320       waist  body weight                               wind sprints
# 1321  upper legs  body weight                     world greatest stretch
# 1322  lower arms  body weight                              wrist circles
# 1323  lower arms     weighted                             wrist rollerer
#
#           target secondaryMuscles/0 secondaryMuscles/1
# 0            abs        hip flexors         lower back
# 1            abs           obliques                NaN
# 2            abs        hip flexors                NaN
# 3          quads         hamstrings             glutes
# 4            abs           obliques                NaN
# ...          ...                ...                ...
# 1319   pectorals            triceps          shoulders
# 1320         abs         quadriceps         hamstrings
# 1321  hamstrings             glutes         quadriceps
# 1322    forearms              hands             wrists
# 1323    forearms             biceps            triceps
#
# [1324 rows x 6 columns]

# %%
# Rename Columns
df.rename(columns={"bodyPart" : "body_part"}, inplace=True)

# %%
df
# Out:
#        body_part    equipment                                       name  \
# 0          waist  body weight                                 3/4 sit-up
# 1          waist  body weight                              45° side bend
# 2          waist  body weight                                   air bike
# 3     upper legs  body weight                    all fours squad stretch
# 4          waist  body weight                    alternate heel touchers
# ...          ...          ...                                        ...
# 1319       chest  body weight  wide-grip chest dip on high parallel bars
# 1320       waist  body weight                               wind sprints
# 1321  upper legs  body weight                     world greatest stretch
# 1322  lower arms  body weight                              wrist circles
# 1323  lower arms     weighted                             wrist rollerer
#
#           target secondaryMuscles/0 secondaryMuscles/1
# 0            abs        hip flexors         lower back
# 1            abs           obliques                NaN
# 2            abs        hip flexors                NaN
# 3          quads         hamstrings             glutes
# 4            abs           obliques                NaN
# ...          ...                ...                ...
# 1319   pectorals            triceps          shoulders
# 1320         abs         quadriceps         hamstrings
# 1321  hamstrings             glutes         quadriceps
# 1322    forearms              hands             wrists
# 1323    forearms             biceps            triceps
#
# [1324 rows x 6 columns]

# %%
# Merge the remaining columns of secondary muscles

## Identify the columns of secondary muscles that will be removed
sec_cols = [col for col in df.columns if col.startswith("secondaryMuscles/")]

df["secondary_muscles_full"] = df[sec_cols].apply(
    lambda x: ", ".join([str(i) for i in x if pd.notnull(i)]),
    axis=1
)

# Removal of unnecessary secondary muscle columns
df.drop(columns=sec_cols, inplace=True)

# %%
df
# Out:
#        body_part    equipment                                       name  \
# 0          waist  body weight                                 3/4 sit-up
# 1          waist  body weight                              45° side bend
# 2          waist  body weight                                   air bike
# 3     upper legs  body weight                    all fours squad stretch
# 4          waist  body weight                    alternate heel touchers
# ...          ...          ...                                        ...
# 1319       chest  body weight  wide-grip chest dip on high parallel bars
# 1320       waist  body weight                               wind sprints
# 1321  upper legs  body weight                     world greatest stretch
# 1322  lower arms  body weight                              wrist circles
# 1323  lower arms     weighted                             wrist rollerer
#
#           target   secondary_muscles_full
# 0            abs  hip flexors, lower back
# 1            abs                 obliques
# 2            abs              hip flexors
# 3          quads       hamstrings, glutes
# 4            abs                 obliques
# ...          ...                      ...
# 1319   pectorals       triceps, shoulders
# 1320         abs   quadriceps, hamstrings
# 1321  hamstrings       glutes, quadriceps
# 1322    forearms            hands, wrists
# 1323    forearms          biceps, triceps
#
# [1324 rows x 5 columns]

# %%
# Add a difficulty column (beginner, intermediate, advanced)
def classify_difficulty(equipment, target):

    beginner_equip = ['body weight', 'assisted', 'ball']
    intermediate_equip = ['dumbbell', 'band', 'rope', 'roller', 'cable']
    advanced_equip = ['barbell', 'smith machine', 'kettlebell',
                      'trap bar', 'sled machine', 'stepmill machine']

    easy_targets = ['abs', 'biceps', 'forearms']
    medium_targets = ['quads', 'hamstrings', 'glutes', 'adductors', 'delts']
    hard_targets = ['pectorals', 'lats', 'traps', 'upper back', 'spine']

    # Classify based on the equipment
    if any(eq in equipment for eq in beginner_equip):
        difficulty = "beginner"
    elif any(eq in equipment for eq in intermediate_equip):
        difficulty = "intermediate"
    elif any(eq in equipment for eq in advanced_equip):
        difficulty = "advanced"
    else:
        difficulty = "intermediate"

    # Adjust based on the target
    if target in easy_targets and difficulty == "intermediate":
        return "beginner"
    elif target in hard_targets and difficulty == "intermediate":
        return "advanced"
    else:
        return difficulty

# Apply on df
df["difficulty"] = df.apply(lambda x: classify_difficulty(x["equipment"], x["target"]), axis=1)

# %%
# See how many beginner, intermediate and advanced exercices we have in dataset 1
df.groupby("difficulty").count()
# Out:
#               body_part  equipment  name  target  secondary_muscles_full
# difficulty
# advanced            473        473   473     473                     473
# beginner            574        574   574     574                     574
# intermediate        277        277   277     277                     277

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1324 entries, 0 to 1323
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   body_part               1324 non-null   object
#  1   equipment               1324 non-null   object
#  2   name                    1324 non-null   object
#  3   target                  1324 non-null   object
#  4   secondary_muscles_full  1324 non-null   object
#  5   difficulty              1324 non-null   object
# dtypes: object(6)
# memory usage: 62.2+ KB

# %% [markdown]
# # **Preprocessing of Dataset 2**

# %%
# Upload dataset 2 into pandas
df2 = pd.read_excel("Dataset2.xlsx")
df2.head()
# Out:
#    Unnamed: 0                              Exercise  \
# 0         NaN               Stability Ball Dead Bug
# 1         NaN               Bodyweight Glute Bridge
# 2         NaN                   Bodyweight Bird Dog
# 3         NaN         Stability Ball Russian Twist
# 4         NaN  Stability Ball Feet Elevated Crunch
#
#   Short YouTube Demonstration In-Depth YouTube Explanation Difficulty Level  \
# 0         Video Demonstration            Video Explanation         Beginner
# 1         Video Demonstration            Video Explanation         Beginner
# 2         Video Demonstration            Video Explanation         Beginner
# 3         Video Demonstration            Video Explanation         Beginner
# 4         Video Demonstration            Video Explanation         Beginner
#
#   Target Muscle Group  Prime Mover Muscle  Secondary Muscle Tertiary Muscle  \
# 0           Abdominals   Rectus Abdominis          Obliques  Rectus Femoris
# 1               Glutes    Gluteus Maximus    Biceps Femoris  Erector Spinae
# 2           Abdominals   Rectus Abdominis   Gluteus Maximus  Erector Spinae
# 3           Abdominals           Obliques  Rectus Abdominis       Iliopsoas
# 4           Abdominals   Rectus Abdominis         Iliopsoas        Obliques
#
#   Primary Equipment   ...  Movement Pattern #2 Movement Pattern #3  \
# 0     Stability Ball  ...                  NaN                 NaN
# 1         Bodyweight  ...                  NaN                 NaN
# 2         Bodyweight  ...                  NaN                 NaN
# 3     Stability Ball  ...                  NaN                 NaN
# 4     Stability Ball  ...                  NaN                 NaN
#
#    Plane Of Motion #1 Plane Of Motion #2 Plane Of Motion #3 Body Region  \
# 0      Sagittal Plane                NaN                NaN        Core
# 1      Sagittal Plane                NaN                NaN  Lower Body
# 2      Sagittal Plane                NaN                NaN        Core
# 3    Transverse Plane                NaN                NaN        Core
# 4      Sagittal Plane                NaN                NaN        Core
#
#   Force Type  Mechanics     Laterality Primary Exercise Classification
# 0      Other   Compound  Contralateral                        Postural
# 1  Unsorted*   Compound      Bilateral                    Bodybuilding
# 2      Other   Compound  Contralateral                        Postural
# 3      Other   Compound      Bilateral                       Unsorted*
# 4      Other  Isolation      Bilateral                       Unsorted*
#
# [5 rows x 32 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3242 entries, 0 to 3241
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       0 non-null      float64
#  1   Exercise                         3242 non-null   object
#  2   Short YouTube Demonstration      2013 non-null   object
#  3   In-Depth YouTube Explanation     950 non-null    object
#  4   Difficulty Level                 3242 non-null   object
#  5   Target Muscle Group              3242 non-null   object
#  6   Prime Mover Muscle               3242 non-null   object
#  7   Secondary Muscle                 2831 non-null   object
#  8   Tertiary Muscle                  2047 non-null   object
#  9   Primary Equipment                3242 non-null   object
#  10  # Primary Items                  3242 non-null   int64
#  11  Secondary Equipment              688 non-null    object
#  12  # Secondary Items                3242 non-null   int64
#  13  Posture                          3242 non-null   object
#  14  Single or Double Arm             3242 non-null   object
#  15  Continuous or Alternating Arms   3242 non-null   object
#  16  Grip                             3242 non-null   object
#  17  Load Position (Ending)           3242 non-null   object
#  18  Continuous or Alternating Legs   3242 non-null   object
#  19  Foot Elevation                   3242 non-null   object
#  20  Combination Exercises            3242 non-null   object
#  21  Movement Pattern #1              3242 non-null   object
#  22  Movement Pattern #2              461 non-null    object
#  23  Movement Pattern #3              37 non-null     object
#  24  Plane Of Motion #1               3238 non-null   object
#  25  Plane Of Motion #2               53 non-null     object
#  26  Plane Of Motion #3               1 non-null      object
#  27  Body Region                      3242 non-null   object
#  28  Force Type                       3242 non-null   object
#  29  Mechanics                        3229 non-null   object
#  30  Laterality                       3242 non-null   object
#  31  Primary Exercise Classification  3242 non-null   object
# dtypes: float64(1), int64(2), object(29)
# memory usage: 810.6+ KB

# %%
# See how many difficulty levels we have and how many exercices for each level
df2.groupby("Difficulty Level").count()
# Out:
#                   Unnamed: 0  Exercise  Short YouTube Demonstration  \
# Difficulty Level
# Advanced                   0       462                          208
# Beginner                   0       414                          360
# Expert                     0       126                           70
# Grand Master               0         8                            4
# Intermediate               0      1092                          622
# Legendary                  0         3                            1
# Master                     0        32                           14
# Novice                     0      1105                          734
#
#                   In-Depth YouTube Explanation  Target Muscle Group   \
# Difficulty Level
# Advanced                                    93                   462
# Beginner                                   195                   414
# Expert                                      39                   126
# Grand Master                                 1                     8
# Intermediate                               303                  1092
# Legendary                                    0                     3
# Master                                       8                    32
# Novice                                     311                  1105
#
#                   Prime Mover Muscle  Secondary Muscle  Tertiary Muscle  \
# Difficulty Level
# Advanced                         462               396              250
# Beginner                         414               371              284
# Expert                           126                91               39
# Grand Master                       8                 4                3
# Intermediate                    1092               961              650
# Legendary                          3                 3                3
# Master                            32                23                6
# Novice                          1105               982              812
#
#                   Primary Equipment   # Primary Items  ...  \
# Difficulty Level                                       ...
# Advanced                         462              462  ...
# Beginner                         414              414  ...
# Expert                           126              126  ...
# Grand Master                       8                8  ...
# Intermediate                    1092             1092  ...
# Legendary                          3                3  ...
# Master                            32               32  ...
# Novice                          1105             1105  ...
#
#                   Movement Pattern #2  Movement Pattern #3  \
# Difficulty Level
# Advanced                           99                    9
# Beginner                           15                    2
# Expert                             30                    4
# Grand Master                        3                    0
# Intermediate                      195                   20
# Legendary                           3                    0
# Master                              5                    0
# Novice                            111                    2
#
#                   Plane Of Motion #1  Plane Of Motion #2  Plane Of Motion #3  \
# Difficulty Level
# Advanced                         462                  13                   1
# Beginner                         411                  10                   0
# Expert                           126                   4                   0
# Grand Master                       8                   0                   0
# Intermediate                    1091                  22                   0
# Legendary                          3                   0                   0
# Master                            32                   0                   0
# Novice                          1105                   4                   0
#
#                   Body Region  Force Type  Mechanics  Laterality  \
# Difficulty Level
# Advanced                  462         462        461         462
# Beginner                  414         414        413         414
# Expert                    126         126        126         126
# Grand Master                8           8          8           8
# Intermediate             1092        1092       1087        1092
# Legendary                   3           3          3           3
# Master                     32          32         32          32
# Novice                   1105        1105       1099        1105
#
#                   Primary Exercise Classification
# Difficulty Level
# Advanced                                      462
# Beginner                                      414
# Expert                                        126
# Grand Master                                    8
# Intermediate                                 1092
# Legendary                                       3
# Master                                         32
# Novice                                       1105
#
# [8 rows x 31 columns]

# %%
# Display the Columns
print(df2.columns.tolist())
# Out:
# ['Unnamed: 0', 'Exercise', 'Short YouTube Demonstration', 'In-Depth YouTube Explanation', 'Difficulty Level', 'Target Muscle Group ', 'Prime Mover Muscle', 'Secondary Muscle', 'Tertiary Muscle', 'Primary Equipment ', '# Primary Items', 'Secondary Equipment', '# Secondary Items', 'Posture', 'Single or Double Arm', 'Continuous or Alternating Arms ', 'Grip', 'Load Position (Ending)', 'Continuous or Alternating Legs ', 'Foot Elevation', 'Combination Exercises', 'Movement Pattern #1', 'Movement Pattern #2', 'Movement Pattern #3', 'Plane Of Motion #1', 'Plane Of Motion #2', 'Plane Of Motion #3', 'Body Region', 'Force Type', 'Mechanics', 'Laterality', 'Primary Exercise Classification']

# %%
# Deletion of unnecessary columns
df2.drop([
    "Unnamed: 0",
    "Short YouTube Demonstration",
    "In-Depth YouTube Explanation",
    "# Primary Items",
    "# Secondary Items",
    "Posture",
    "Single or Double Arm",
    "Continuous or Alternating Arms ",
    "Grip",
    "Load Position (Ending)",
    "Continuous or Alternating Legs ",
    "Foot Elevation",
    "Combination Exercises",
    "Movement Pattern #1",
    "Movement Pattern #2",
    "Movement Pattern #3",
    "Plane Of Motion #1",
    "Plane Of Motion #2",
    "Plane Of Motion #3",
    "Force Type",
    "Mechanics",
    "Laterality",
    "Primary Exercise Classification"
], axis=1, inplace=True)

# %%
df2.head()
# Out:
#                                Exercise Difficulty Level Target Muscle Group   \
# 0               Stability Ball Dead Bug         Beginner           Abdominals
# 1               Bodyweight Glute Bridge         Beginner               Glutes
# 2                   Bodyweight Bird Dog         Beginner           Abdominals
# 3         Stability Ball Russian Twist          Beginner           Abdominals
# 4  Stability Ball Feet Elevated Crunch          Beginner           Abdominals
#
#   Prime Mover Muscle  Secondary Muscle Tertiary Muscle Primary Equipment   \
# 0   Rectus Abdominis          Obliques  Rectus Femoris     Stability Ball
# 1    Gluteus Maximus    Biceps Femoris  Erector Spinae         Bodyweight
# 2   Rectus Abdominis   Gluteus Maximus  Erector Spinae         Bodyweight
# 3           Obliques  Rectus Abdominis       Iliopsoas     Stability Ball
# 4   Rectus Abdominis         Iliopsoas        Obliques     Stability Ball
#
#   Secondary Equipment Body Region
# 0                 NaN        Core
# 1                 NaN  Lower Body
# 2                 NaN        Core
# 3                 NaN        Core
# 4                 NaN        Core

# %%
# Remove the unnecessary spaces from the columns names
df2.columns = df2.columns.str.strip().str.lower()
print(df2.columns.tolist())
# Out:
# ['exercise', 'difficulty level', 'target muscle group', 'prime mover muscle', 'secondary muscle', 'tertiary muscle', 'primary equipment', 'secondary equipment', 'body region']

# %%
# Rename Target Muscle Group -> target
df2.rename(columns={"target muscle group": "target"}, inplace=True)
df2
# Out:
#                                          exercise difficulty level  \
# 0                         Stability Ball Dead Bug         Beginner
# 1                         Bodyweight Glute Bridge         Beginner
# 2                             Bodyweight Bird Dog         Beginner
# 3                   Stability Ball Russian Twist          Beginner
# 4            Stability Ball Feet Elevated Crunch          Beginner
# ...                                           ...              ...
# 3237      Slider Sandbag Front Rack Reverse Lunge           Novice
# 3238       Slider Sandbag Back Rack Reverse Lunge           Novice
# 3239  Cable Straight Bar Reverse Grip Front Raise           Novice
# 3240              EZ Bar Reverse Grip Front Raise           Novice
# 3241                                  Sled Sprint     Intermediate
#
#           target  prime mover muscle  secondary muscle  tertiary muscle  \
# 0     Abdominals    Rectus Abdominis          Obliques   Rectus Femoris
# 1         Glutes     Gluteus Maximus    Biceps Femoris   Erector Spinae
# 2     Abdominals    Rectus Abdominis   Gluteus Maximus   Erector Spinae
# 3     Abdominals            Obliques  Rectus Abdominis        Iliopsoas
# 4     Abdominals    Rectus Abdominis         Iliopsoas         Obliques
# ...          ...                 ...               ...              ...
# 3237  Quadriceps  Quadriceps Femoris   Gluteus Maximus  Adductor Magnus
# 3238  Quadriceps  Quadriceps Femoris   Gluteus Maximus  Adductor Magnus
# 3239   Shoulders   Anterior Deltoids  Pectoralis Major              NaN
# 3240   Shoulders   Anterior Deltoids  Pectoralis Major              NaN
# 3241  Quadriceps  Quadriceps Femoris   Gluteus Maximus    Gastrocnemius
#
#      primary equipment secondary equipment body region
# 0       Stability Ball                 NaN        Core
# 1           Bodyweight                 NaN  Lower Body
# 2           Bodyweight                 NaN        Core
# 3       Stability Ball                 NaN        Core
# 4       Stability Ball                 NaN        Core
# ...                ...                 ...         ...
# 3237           Sliders             Sandbag  Lower Body
# 3238           Sliders             Sandbag  Lower Body
# 3239             Cable                 NaN  Upper Body
# 3240            EZ Bar                 NaN  Upper Body
# 3241              Sled                 NaN  Lower Body
#
# [3242 rows x 9 columns]

# %%
# Merge the Secondary Muscles Columns
sec_cols = ["prime mover muscle" , "secondary muscle" , "tertiary muscle"]

df2["secondary_muscles_full"] = df2[sec_cols].apply(
    lambda x: ", ".join([str(i) for i in x if pd.notnull(i)]),
    axis=1
)

df2.drop(columns=sec_cols, inplace=True)

# %%
df2
# Out:
#                                          exercise difficulty level  \
# 0                         Stability Ball Dead Bug         Beginner
# 1                         Bodyweight Glute Bridge         Beginner
# 2                             Bodyweight Bird Dog         Beginner
# 3                   Stability Ball Russian Twist          Beginner
# 4            Stability Ball Feet Elevated Crunch          Beginner
# ...                                           ...              ...
# 3237      Slider Sandbag Front Rack Reverse Lunge           Novice
# 3238       Slider Sandbag Back Rack Reverse Lunge           Novice
# 3239  Cable Straight Bar Reverse Grip Front Raise           Novice
# 3240              EZ Bar Reverse Grip Front Raise           Novice
# 3241                                  Sled Sprint     Intermediate
#
#           target primary equipment secondary equipment body region  \
# 0     Abdominals    Stability Ball                 NaN        Core
# 1         Glutes        Bodyweight                 NaN  Lower Body
# 2     Abdominals        Bodyweight                 NaN        Core
# 3     Abdominals    Stability Ball                 NaN        Core
# 4     Abdominals    Stability Ball                 NaN        Core
# ...          ...               ...                 ...         ...
# 3237  Quadriceps           Sliders             Sandbag  Lower Body
# 3238  Quadriceps           Sliders             Sandbag  Lower Body
# 3239   Shoulders             Cable                 NaN  Upper Body
# 3240   Shoulders            EZ Bar                 NaN  Upper Body
# 3241  Quadriceps              Sled                 NaN  Lower Body
#
#                                  secondary_muscles_full
# 0            Rectus Abdominis, Obliques, Rectus Femoris
# 1       Gluteus Maximus, Biceps Femoris, Erector Spinae
# 2     Rectus Abdominis, Gluteus Maximus, Erector Spinae
# 3                 Obliques, Rectus Abdominis, Iliopsoas
# 4                 Rectus Abdominis, Iliopsoas, Obliques
# ...                                                 ...
# 3237  Quadriceps Femoris, Gluteus Maximus, Adductor ...
# 3238  Quadriceps Femoris, Gluteus Maximus, Adductor ...
# 3239                Anterior Deltoids, Pectoralis Major
# 3240                Anterior Deltoids, Pectoralis Major
# 3241  Quadriceps Femoris, Gluteus Maximus, Gastrocne...
#
# [3242 rows x 7 columns]

# %%
# Merge the Equipment Columns
equ_cols = ["primary equipment" , "secondary equipment"]

df2["equipment"] = df2[equ_cols].apply(
    lambda x: ", ".join([str(i) for i in x if pd.notnull(i)]),
    axis=1
)

df2.drop(columns=equ_cols, inplace=True)

# %%
df2
# Out:
#                                          exercise difficulty level  \
# 0                         Stability Ball Dead Bug         Beginner
# 1                         Bodyweight Glute Bridge         Beginner
# 2                             Bodyweight Bird Dog         Beginner
# 3                   Stability Ball Russian Twist          Beginner
# 4            Stability Ball Feet Elevated Crunch          Beginner
# ...                                           ...              ...
# 3237      Slider Sandbag Front Rack Reverse Lunge           Novice
# 3238       Slider Sandbag Back Rack Reverse Lunge           Novice
# 3239  Cable Straight Bar Reverse Grip Front Raise           Novice
# 3240              EZ Bar Reverse Grip Front Raise           Novice
# 3241                                  Sled Sprint     Intermediate
#
#           target body region  \
# 0     Abdominals        Core
# 1         Glutes  Lower Body
# 2     Abdominals        Core
# 3     Abdominals        Core
# 4     Abdominals        Core
# ...          ...         ...
# 3237  Quadriceps  Lower Body
# 3238  Quadriceps  Lower Body
# 3239   Shoulders  Upper Body
# 3240   Shoulders  Upper Body
# 3241  Quadriceps  Lower Body
#
#                                  secondary_muscles_full         equipment
# 0            Rectus Abdominis, Obliques, Rectus Femoris    Stability Ball
# 1       Gluteus Maximus, Biceps Femoris, Erector Spinae        Bodyweight
# 2     Rectus Abdominis, Gluteus Maximus, Erector Spinae        Bodyweight
# 3                 Obliques, Rectus Abdominis, Iliopsoas    Stability Ball
# 4                 Rectus Abdominis, Iliopsoas, Obliques    Stability Ball
# ...                                                 ...               ...
# 3237  Quadriceps Femoris, Gluteus Maximus, Adductor ...  Sliders, Sandbag
# 3238  Quadriceps Femoris, Gluteus Maximus, Adductor ...  Sliders, Sandbag
# 3239                Anterior Deltoids, Pectoralis Major             Cable
# 3240                Anterior Deltoids, Pectoralis Major            EZ Bar
# 3241  Quadriceps Femoris, Gluteus Maximus, Gastrocne...              Sled
#
# [3242 rows x 6 columns]

# %%
# Rename Columns
df2.rename(columns={"exercise": "name" , "difficulty level": "difficulty" , "body region" : "body_part"}, inplace=True)
df2
# Out:
#                                              name    difficulty      target  \
# 0                         Stability Ball Dead Bug      Beginner  Abdominals
# 1                         Bodyweight Glute Bridge      Beginner      Glutes
# 2                             Bodyweight Bird Dog      Beginner  Abdominals
# 3                   Stability Ball Russian Twist       Beginner  Abdominals
# 4            Stability Ball Feet Elevated Crunch       Beginner  Abdominals
# ...                                           ...           ...         ...
# 3237      Slider Sandbag Front Rack Reverse Lunge        Novice  Quadriceps
# 3238       Slider Sandbag Back Rack Reverse Lunge        Novice  Quadriceps
# 3239  Cable Straight Bar Reverse Grip Front Raise        Novice   Shoulders
# 3240              EZ Bar Reverse Grip Front Raise        Novice   Shoulders
# 3241                                  Sled Sprint  Intermediate  Quadriceps
#
#        body_part                             secondary_muscles_full  \
# 0           Core         Rectus Abdominis, Obliques, Rectus Femoris
# 1     Lower Body    Gluteus Maximus, Biceps Femoris, Erector Spinae
# 2           Core  Rectus Abdominis, Gluteus Maximus, Erector Spinae
# 3           Core              Obliques, Rectus Abdominis, Iliopsoas
# 4           Core              Rectus Abdominis, Iliopsoas, Obliques
# ...          ...                                                ...
# 3237  Lower Body  Quadriceps Femoris, Gluteus Maximus, Adductor ...
# 3238  Lower Body  Quadriceps Femoris, Gluteus Maximus, Adductor ...
# 3239  Upper Body                Anterior Deltoids, Pectoralis Major
# 3240  Upper Body                Anterior Deltoids, Pectoralis Major
# 3241  Lower Body  Quadriceps Femoris, Gluteus Maximus, Gastrocne...
#
#              equipment
# 0       Stability Ball
# 1           Bodyweight
# 2           Bodyweight
# 3       Stability Ball
# 4       Stability Ball
# ...                ...
# 3237  Sliders, Sandbag
# 3238  Sliders, Sandbag
# 3239             Cable
# 3240            EZ Bar
# 3241              Sled
#
# [3242 rows x 6 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3242 entries, 0 to 3241
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    3242 non-null   object
#  1   difficulty              3242 non-null   object
#  2   target                  3242 non-null   object
#  3   body_part               3242 non-null   object
#  4   secondary_muscles_full  3242 non-null   object
#  5   equipment               3242 non-null   object
# dtypes: object(6)
# memory usage: 152.1+ KB

# %% [markdown]
# # **Concatenate the 2 Datasets**

# %%
# Concatenate
df_all = pd.concat([df, df2])
df_all
# Out:
#        body_part         equipment  \
# 0          waist       body weight
# 1          waist       body weight
# 2          waist       body weight
# 3     upper legs       body weight
# 4          waist       body weight
# ...          ...               ...
# 3237  Lower Body  Sliders, Sandbag
# 3238  Lower Body  Sliders, Sandbag
# 3239  Upper Body             Cable
# 3240  Upper Body            EZ Bar
# 3241  Lower Body              Sled
#
#                                              name      target  \
# 0                                      3/4 sit-up         abs
# 1                                   45° side bend         abs
# 2                                        air bike         abs
# 3                         all fours squad stretch       quads
# 4                         alternate heel touchers         abs
# ...                                           ...         ...
# 3237      Slider Sandbag Front Rack Reverse Lunge  Quadriceps
# 3238       Slider Sandbag Back Rack Reverse Lunge  Quadriceps
# 3239  Cable Straight Bar Reverse Grip Front Raise   Shoulders
# 3240              EZ Bar Reverse Grip Front Raise   Shoulders
# 3241                                  Sled Sprint  Quadriceps
#
#                                  secondary_muscles_full    difficulty
# 0                               hip flexors, lower back      beginner
# 1                                              obliques      beginner
# 2                                           hip flexors      beginner
# 3                                    hamstrings, glutes      beginner
# 4                                              obliques      beginner
# ...                                                 ...           ...
# 3237  Quadriceps Femoris, Gluteus Maximus, Adductor ...        Novice
# 3238  Quadriceps Femoris, Gluteus Maximus, Adductor ...        Novice
# 3239                Anterior Deltoids, Pectoralis Major        Novice
# 3240                Anterior Deltoids, Pectoralis Major        Novice
# 3241  Quadriceps Femoris, Gluteus Maximus, Gastrocne...  Intermediate
#
# [4566 rows x 6 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4566 entries, 0 to 3241
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   body_part               4566 non-null   object
#  1   equipment               4566 non-null   object
#  2   name                    4566 non-null   object
#  3   target                  4566 non-null   object
#  4   secondary_muscles_full  4566 non-null   object
#  5   difficulty              4566 non-null   object
# dtypes: object(6)
# memory usage: 249.7+ KB

# %%
# Delete Duplicates
df_all.drop_duplicates(subset=["name"], inplace=True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4558 entries, 0 to 3241
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   body_part               4558 non-null   object
#  1   equipment               4558 non-null   object
#  2   name                    4558 non-null   object
#  3   target                  4558 non-null   object
#  4   secondary_muscles_full  4558 non-null   object
#  5   difficulty              4558 non-null   object
# dtypes: object(6)
# memory usage: 249.3+ KB

# %%
# Make all the info in lower case
df_all = df_all.applymap(lambda x: x.lower() if isinstance(x, str) else x)
df_all
# Out:
# /tmp/ipython-input-443306991.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_all = df_all.applymap(lambda x: x.lower() if isinstance(x, str) else x)
#        body_part         equipment  \
# 0          waist       body weight
# 1          waist       body weight
# 2          waist       body weight
# 3     upper legs       body weight
# 4          waist       body weight
# ...          ...               ...
# 3237  lower body  sliders, sandbag
# 3238  lower body  sliders, sandbag
# 3239  upper body             cable
# 3240  upper body            ez bar
# 3241  lower body              sled
#
#                                              name      target  \
# 0                                      3/4 sit-up         abs
# 1                                   45° side bend         abs
# 2                                        air bike         abs
# 3                         all fours squad stretch       quads
# 4                         alternate heel touchers         abs
# ...                                           ...         ...
# 3237      slider sandbag front rack reverse lunge  quadriceps
# 3238       slider sandbag back rack reverse lunge  quadriceps
# 3239  cable straight bar reverse grip front raise   shoulders
# 3240              ez bar reverse grip front raise   shoulders
# 3241                                  sled sprint  quadriceps
#
#                                  secondary_muscles_full    difficulty
# 0                               hip flexors, lower back      beginner
# 1                                              obliques      beginner
# 2                                           hip flexors      beginner
# 3                                    hamstrings, glutes      beginner
# 4                                              obliques      beginner
# ...                                                 ...           ...
# 3237  quadriceps femoris, gluteus maximus, adductor ...        novice
# 3238  quadriceps femoris, gluteus maximus, adductor ...        novice
# 3239                anterior deltoids, pectoralis major        novice
# 3240                anterior deltoids, pectoralis major        novice
# 3241  quadriceps femoris, gluteus maximus, gastrocne...  intermediate
#
# [4558 rows x 6 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4558 entries, 0 to 3241
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   body_part               4558 non-null   object
#  1   equipment               4558 non-null   object
#  2   name                    4558 non-null   object
#  3   target                  4558 non-null   object
#  4   secondary_muscles_full  4558 non-null   object
#  5   difficulty              4558 non-null   object
# dtypes: object(6)
# memory usage: 249.3+ KB

# %%
# Make the difficulty levels united: beginner, intermediate and advanced
df_all["difficulty"].replace({
    "novice": "beginner",
    "master": "advanced",
    "legendary": "advanced",
    "grand master": "advanced",
    "expert": "advanced"
}, inplace=True)

# %%
df_all.groupby("difficulty").count()
# Out:
#               body_part  equipment  name  target  secondary_muscles_full
# difficulty
# advanced           1100       1100  1100    1100                    1100
# beginner           2090       2090  2090    2090                    2090
# intermediate       1368       1368  1368    1368                    1368

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4558 entries, 0 to 3241
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   body_part               4558 non-null   object
#  1   equipment               4558 non-null   object
#  2   name                    4558 non-null   object
#  3   target                  4558 non-null   object
#  4   secondary_muscles_full  4558 non-null   object
#  5   difficulty              4558 non-null   object
# dtypes: object(6)
# memory usage: 249.3+ KB

# %%
# Get the unique values of the column "target"
print(df_all["target"].unique())
# Out:
# ['abs' 'quads' 'lats' 'calves' 'pectorals' 'glutes' 'hamstrings'
#  'adductors' 'triceps' 'cardiovascular system' 'spine' 'upper back'
#  'biceps' 'delts' 'forearms' 'traps' 'serratus anterior' 'abductors'
#  'levator scapulae' 'abdominals' 'chest' 'hip flexors' 'shoulders' 'back'
#  'quadriceps' 'trapezius' 'shins' 'trapezius ']

# %%
# Unify duplicate targets
df_all['target'] = df_all['target'].replace({
    'abs': 'abdominals',
    'quads': 'quadriceps',
    'traps': 'trapezius',
    'chest': 'pectorals',
    'delts': 'shoulders'
})

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4558 entries, 0 to 3241
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   body_part               4558 non-null   object
#  1   equipment               4558 non-null   object
#  2   name                    4558 non-null   object
#  3   target                  4558 non-null   object
#  4   secondary_muscles_full  4558 non-null   object
#  5   difficulty              4558 non-null   object
# dtypes: object(6)
# memory usage: 249.3+ KB

# %%
df_all.groupby("target").count()
# Out:
#                        body_part  equipment  name  secondary_muscles_full  \
# target
# abdominals                   601        601   601                     601
# abductors                     27         27    27                      27
# adductors                     26         26    26                      26
# back                         182        182   182                     182
# biceps                       264        264   264                     264
# calves                       106        106   106                     106
# cardiovascular system         29         29    29                      29
# forearms                      65         65    65                      65
# glutes                       325        325   325                     325
# hamstrings                    68         68    68                      68
# hip flexors                   53         53    53                      53
# lats                          81         81    81                      81
# levator scapulae               2          2     2                       2
# pectorals                    327        327   327                     327
# quadriceps                  1363       1363  1363                    1363
# serratus anterior              5          5     5                       5
# shins                          6          6     6                       6
# shoulders                    656        656   656                     656
# spine                         19         19    19                      19
# trapezius                     32         32    32                      32
# trapezius                      2          2     2                       2
# triceps                      231        231   231                     231
# upper back                    88         88    88                      88
#
#                        difficulty
# target
# abdominals                    601
# abductors                      27
# adductors                      26
# back                          182
# biceps                        264
# calves                        106
# cardiovascular system          29
# forearms                       65
# glutes                        325
# hamstrings                     68
# hip flexors                    53
# lats                           81
# levator scapulae                2
# pectorals                     327
# quadriceps                   1363
# serratus anterior               5
# shins                           6
# shoulders                     656
# spine                          19
# trapezius                      32
# trapezius                       2
# triceps                       231
# upper back                     88

# %%
df_all['target'].unique()
# Out:
# array(['abdominals', 'quadriceps', 'lats', 'calves', 'pectorals',
#        'glutes', 'hamstrings', 'adductors', 'triceps',
#        'cardiovascular system', 'spine', 'upper back', 'biceps',
#        'shoulders', 'forearms', 'trapezius', 'serratus anterior',
#        'abductors', 'levator scapulae', 'hip flexors', 'back', 'shins',
#        'trapezius '], dtype=object)

# %%
# trapezius (with space) -> trapezius without space
df_all["target"].replace(
    {"trapezius ": "trapezius"}
,inplace=True)

# %%
df_all.groupby("target").count()
# Out:
#                        body_part  equipment  name  secondary_muscles_full  \
# target
# abdominals                   601        601   601                     601
# abductors                     27         27    27                      27
# adductors                     26         26    26                      26
# back                         182        182   182                     182
# biceps                       264        264   264                     264
# calves                       106        106   106                     106
# cardiovascular system         29         29    29                      29
# forearms                      65         65    65                      65
# glutes                       325        325   325                     325
# hamstrings                    68         68    68                      68
# hip flexors                   53         53    53                      53
# lats                          81         81    81                      81
# levator scapulae               2          2     2                       2
# pectorals                    327        327   327                     327
# quadriceps                  1363       1363  1363                    1363
# serratus anterior              5          5     5                       5
# shins                          6          6     6                       6
# shoulders                    656        656   656                     656
# spine                         19         19    19                      19
# trapezius                     34         34    34                      34
# triceps                      231        231   231                     231
# upper back                    88         88    88                      88
#
#                        difficulty
# target
# abdominals                    601
# abductors                      27
# adductors                      26
# back                          182
# biceps                        264
# calves                        106
# cardiovascular system          29
# forearms                       65
# glutes                        325
# hamstrings                     68
# hip flexors                    53
# lats                           81
# levator scapulae                2
# pectorals                     327
# quadriceps                   1363
# serratus anterior               5
# shins                           6
# shoulders                     656
# spine                          19
# trapezius                      34
# triceps                       231
# upper back                     88

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4558 entries, 0 to 3241
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   body_part               4558 non-null   object
#  1   equipment               4558 non-null   object
#  2   name                    4558 non-null   object
#  3   target                  4558 non-null   object
#  4   secondary_muscles_full  4558 non-null   object
#  5   difficulty              4558 non-null   object
# dtypes: object(6)
# memory usage: 249.3+ KB

# %% [markdown]
# # **Add the columns "sets" and "reps"**

# %%
# Generate the sets and reps based on the difficulty levels
import random

def generate_sets_reps(difficulty):
    if difficulty == "beginner":
        sets = random.randint(2, 3)
        reps = random.choice(["10-12", "12-15"])
    elif difficulty == "intermediate":
        sets = random.randint(3, 4)
        reps = random.choice(["12-15", "15-18"])
    else:
        sets = random.randint(4, 5)
        reps = random.choice(["8-10", "10-12"])
    return sets, reps

# %%
# Apply and add these 2 columns
df_all[["sets", "reps"]] = df_all["difficulty"].apply(
    lambda d: pd.Series(generate_sets_reps(d))
)

# %%
df_all
# Out:
#        body_part         equipment  \
# 0          waist       body weight
# 1          waist       body weight
# 2          waist       body weight
# 3     upper legs       body weight
# 4          waist       body weight
# ...          ...               ...
# 3237  lower body  sliders, sandbag
# 3238  lower body  sliders, sandbag
# 3239  upper body             cable
# 3240  upper body            ez bar
# 3241  lower body              sled
#
#                                              name      target  \
# 0                                      3/4 sit-up  abdominals
# 1                                   45° side bend  abdominals
# 2                                        air bike  abdominals
# 3                         all fours squad stretch  quadriceps
# 4                         alternate heel touchers  abdominals
# ...                                           ...         ...
# 3237      slider sandbag front rack reverse lunge  quadriceps
# 3238       slider sandbag back rack reverse lunge  quadriceps
# 3239  cable straight bar reverse grip front raise   shoulders
# 3240              ez bar reverse grip front raise   shoulders
# 3241                                  sled sprint  quadriceps
#
#                                  secondary_muscles_full    difficulty  sets  \
# 0                               hip flexors, lower back      beginner     3
# 1                                              obliques      beginner     3
# 2                                           hip flexors      beginner     2
# 3                                    hamstrings, glutes      beginner     3
# 4                                              obliques      beginner     2
# ...                                                 ...           ...   ...
# 3237  quadriceps femoris, gluteus maximus, adductor ...      beginner     2
# 3238  quadriceps femoris, gluteus maximus, adductor ...      beginner     3
# 3239                anterior deltoids, pectoralis major      beginner     2
# 3240                anterior deltoids, pectoralis major      beginner     2
# 3241  quadriceps femoris, gluteus maximus, gastrocne...  intermediate     3
#
#        reps
# 0     10-12
# 1     10-12
# 2     10-12
# 3     10-12
# 4     12-15
# ...     ...
# 3237  12-15
# 3238  12-15
# 3239  12-15
# 3240  10-12
# 3241  15-18
#
# [4558 rows x 8 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4558 entries, 0 to 3241
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   body_part               4558 non-null   object
#  1   equipment               4558 non-null   object
#  2   name                    4558 non-null   object
#  3   target                  4558 non-null   object
#  4   secondary_muscles_full  4558 non-null   object
#  5   difficulty              4558 non-null   object
#  6   sets                    4558 non-null   int64
#  7   reps                    4558 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 320.5+ KB

# %% [markdown]
# # **Save the Resulting Dataset**

# %%
df_all.to_csv("fitgenai_dataset.csv", index=False)
